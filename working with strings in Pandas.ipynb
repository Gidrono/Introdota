# %%
import pandas as pd

# %%
df = pd.read_csv("James Bond 007 Movie Data.csv")
df.head()
# Out:
#                     Film  Year  Years lapse    Bond actor  \
# 0                 Dr. No  1962          NaN  Sean Connery
# 1  From Russia With Love  1963          1.0  Sean Connery
# 2             Goldfinger  1964          1.0  Sean Connery
# 3            Thunderball  1965          1.0  Sean Connery
# 4    You Only Live Twice  1967          2.0  Sean Connery
#
#    Bond actor appearance  Villians Dispatched  Others' Dispatched  \
# 0                      1                    4                   8
# 1                      2                   11                  16
# 2                      3                    9                  68
# 3                      4                   20                  90
# 4                      5                   21                 175
#
#    Total Dispatched  Adjusted box office  Actual box office  ...  \
# 0                12                448.8               59.5  ...
# 1                27                543.8               78.9  ...
# ...

# %% [markdown]
# # string methods from python works also in pandas
# some examples

# %%
df["Bond actor"].str.capitalize().unique()
# Out:
# array(['Sean connery', 'George lazenby', 'Roger moore', 'Timothy dalton',
#        'Pierce brosnan', 'Daniel craig'], dtype=object)

# %%
df["Bond actor"].str.find("Connery") # remember that find return the index and -1 if not exist
df["Bond actor"].str.len().head() # return numbers
df["Bond actor"].str.split().head()# return list
df["Bond actor"].str.isalpha().head() #return boolean values. also why False?
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Bond actor, dtype: bool

# %%
df["new_name"] = df["Bond actor"].apply(lambda x: "".join(x.split()))
df["new_name"].str.isalpha().head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: new_name, dtype: bool

# %% [markdown]
# # methods using regex build in
# some example

# %%
df["Bond actor"].str.replace("Sean", "Sir Sean").head() # re.sub()
df["Bond actor"].str.replace("sean", "Sir Sean", case=True).head() # if case = True (default) it mean case sensitive)
df["Bond actor"].str.replace("sean", "Sir Sean", case=False, regex=True).head()# IF REGEX = False treats the pattern as a literal string
# Out:
# 0    Sir Sean Connery
# 1    Sir Sean Connery
# 2    Sir Sean Connery
# 3    Sir Sean Connery
# 4    Sir Sean Connery
# Name: Bond actor, dtype: object

# %%
df[df["Bond actor"].str.contains("S")].tail()# return boolean unless you "wrapped" it again with df
# Out:
#                     Film  Year  Years lapse    Bond actor  \
# 1  From Russia With Love  1963          1.0  Sean Connery
# 2             Goldfinger  1964          1.0  Sean Connery
# 3            Thunderball  1965          1.0  Sean Connery
# 4    You Only Live Twice  1967          2.0  Sean Connery
# 6   Diamonds Are Forever  1971          2.0  Sean Connery
#
#    Bond actor appearance  Villians Dispatched  Others' Dispatched  \
# 1                      2                   11                  16
# 2                      3                    9                  68
# 3                      4                   20                  90
# 4                      5                   21                 175
# 6                      6                    7                  42
#
#    Total Dispatched  Adjusted box office  Actual box office  ...  \
# 1                27                543.8               78.9  ...
# 2                77                820.4              124.9  ...
# ...

# %%
df[df["Bond actor"].str.contains("S|D", case=None)].tail()# (s or d)
# Out:
#                        Film  Year  Years lapse      Bond actor  \
# 18  The World is Not Enough  1999          2.0  Pierce Brosnan
# 19          Die Another Day  2002          3.0  Pierce Brosnan
# 20            Casino Royale  2006          4.0    Daniel Craig
# 21        Quantum of Solace  2008          2.0    Daniel Craig
# 22                  Skyfall  2012          4.0    Daniel Craig
#
#     Bond actor appearance  Villians Dispatched  Others' Dispatched  \
# 18                      3                   27                  43
# 19                      4                   31                  20
# 20                      1                   11                  11
# 21                      2                   16                  15
# 22                      3                   26                  23
#
#     Total Dispatched  Adjusted box office  Actual box office  ...  \
# 18                70                439.5              361.8  ...
# ...

# %%
df[df["Bond actor"].str.contains("S|D", case=None)]#["Bond actor"]

# %%
df[df["Bond actor"].str.contains("^[^S].*[^g]$")] #find all names that not starting with "S" and not ending with a "g", making use of the start-of-string (^) and end-of-string ($)
# Out:
#                                Film  Year  Years lapse      Bond actor  \
# 5   On Her Majesty's Secret Service  1969          2.0  George Lazenby
# 7                  Live and Let Die  1973          2.0     Roger Moore
# 8       The Man with the Golden Gun  1974          1.0     Roger Moore
# 9              The Spy Who Loved Me  1977          3.0     Roger Moore
# 10                        Moonraker  1979          2.0     Roger Moore
# 11               For Your Eyes Only  1981          2.0     Roger Moore
# 12                        Octopussy  1983          2.0     Roger Moore
# 13                 A View to a Kill  1985          2.0     Roger Moore
# 14             The Living Daylights  1987          2.0  Timothy Dalton
# 15                  Licence to Kill  1989          2.0  Timothy Dalton
# 16                        GoldenEye  1995          6.0  Pierce Brosnan
# 17              Tomorrow Never Dies  1997          2.0  Pierce Brosnan
# ...

# %%
df["Bond actor"]
