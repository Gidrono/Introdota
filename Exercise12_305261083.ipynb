# %% [markdown]
# # Exercise 10

# %% [markdown]
# 1. Load the data from the file fortune1000.csv that is attched to this assignment.

# %%
import pandas as pd
fortune = pd.read_csv("fortune1000.csv", index_col="Rank")

fortune.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Company    1000 non-null   object
#  1   Sector     1000 non-null   object
#  2   Industry   1000 non-null   object
#  3   Location   1000 non-null   object
#  4   Revenue    1000 non-null   int64
#  5   Profits    1000 non-null   int64
#  6   Employees  1000 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 62.5+ KB

# %% [markdown]
# 2. a. How many rows and columns does the file has?

# %%
fortune.shape
#1000 rows, 7 columns
# Out:
# (1000, 7)

# %% [markdown]
# 2. b. Print the first 5 rows of the dataframe

# %%
fortune.head(5)
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %% [markdown]
# 3. What is the average revenue of all of the companies? What is the average profit?

# %%
fortune["Revenue"].describe()["mean"]
# Out:
# 13535.525

# %%
fortune["Profits"].describe()["mean"]
# Out:
# 894.093

# %% [markdown]
# 4. Who are the 7 most successful companies (by revenue)?

# %%
fortune.sort_values("Revenue", ascending=False).head(7)
# Out:
#                  Company                Sector  \
# Rank
# 1                Walmart             Retailing
# 2            Exxon Mobil                Energy
# 3                  Apple            Technology
# 4     Berkshire Hathaway            Financials
# 5               McKesson           Health Care
# 6     UnitedHealth Group           Health Care
# 7             CVS Health  Food and Drug Stores
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
# 6      Health Care: Insurance and Managed Care     Minnetonka, MN   157107
# 7                         Food and Drug Stores     Woonsocket, RI   153290
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400
# 6        5813     200000
# 7        5237     199000

# %% [markdown]
# 5. Who are the companies with more than 300,000 employees?

# %%
fortune[fortune["Employees"]>300000]
# Out:
#                        Company                        Sector  \
# Rank
# 218                 Yum Brands  Hotels, Resturants & Leisure
# 109                 McDonald’s  Hotels, Resturants & Leisure
# 58                       FedEx                Transportation
# 48                         UPS                Transportation
# 38                      Target                     Retailing
# 31                         IBM                    Technology
# 28                  Home Depot                     Retailing
# 19    Walgreens Boots Alliance          Food and Drug Stores
# 17                      Kroger          Food and Drug Stores
# 11            General Electric                   Industrials
# 4           Berkshire Hathaway                    Financials
# 1                      Walmart                     Retailing
#
#                                       Industry         Location  Revenue  \
# Rank
# 218                              Food Services   Louisville, KY    13105
# 109                              Food Services    Oak Brook, IL    25413
# 58         Mail, Package, and Freight Delivery      Memphis, TN    47453
# 48         Mail, Package, and Freight Delivery      Atlanta, GA    58363
# 38                       General Merchandisers  Minneapolis, MN    73785
# 31             Information Technology Services       Armonk, NY    82461
# 28                  Specialty Retailers: Other      Atlanta, GA    88519
# 19                        Food and Drug Stores    Deerfield, IL   103444
# 17                        Food and Drug Stores   Cincinnati, OH   109830
# 11                        Industrial Machinery    Fairfield, CT   140389
# 4     Insurance: Property and Casualty (Stock)        Omaha, NE   210821
# 1                        General Merchandisers  Bentonville, AR   482130
#
#       Profits  Employees
# Rank
# 218      1293     505000
# 109      4529     420000
# 58       1050     323035
# 48       4844     341240
# 38       3363     341000
# 31      13190     411798
# 28       7009     385000
# 19       4220     302500
# 17       2039     431000
# 11      -6126     333000
# 4       24083     331000
# 1       14694    2300000

# %% [markdown]
# 6. How many sectors are in the database? How many industries?

# %%
fortune.Sector.nunique()
# Out:
# 21

# %%
fortune.Industry.nunique()
# Out:
# 73

# %% [markdown]
# 7. a. What are the 5 most popular industries (by companies)? How many companies are associated with these industries?

# %%
fortune['Industry'].value_counts()[:5]
# Out:
# Specialty Retailers: Other      42
# Utilities: Gas and Electric     41
# Chemicals                       30
# Commercial Banks                28
# Mining, Crude-Oil Production    28
# Name: Industry, dtype: int64

# %% [markdown]
# 7.b. For each industry, which is the most profitable company? (you might want to use idxmax).

# %%
fortune[fortune['Industry']=='Chemicals'].sort_values("Profits", ascending=False).head(1)
#and for other industries as well
# Out:
#            Company     Sector   Industry     Location  Revenue  Profits  \
# Rank
# 56    Dow Chemical  Chemicals  Chemicals  Midland, MI    48778     7685
#
#       Employees
# Rank
# 56        49495

# %% [markdown]
# 8. a. Split the location column into two new columns named 'City' and 'State'.
# <br>- Use str functions.
# <br>- You can also use unpacking into these two columns

# %%
fortune["City"] = fortune["Location"].str.split()
fortune[["City", "State"]] = fortune['Location'].str.split(',', expand=True)
fortune
# Out:
#                          Company                        Sector  \
# Rank
# 1000           Briggs & Stratton                   Industrials
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 996   New York Community Bancorp                    Financials
# ...                          ...                           ...
# 5                       McKesson                   Health Care
# 4             Berkshire Hathaway                    Financials
# 3                          Apple                    Technology
# 2                    Exxon Mobil                        Energy
# 1                        Walmart                     Retailing
#
#                                       Industry           Location  Revenue  \
# Rank
# 1000                      Industrial Machinery      Wauwatosa, WI     1895
# 999                              Food Services         Dublin, OH     1896
# 997                Utilities: Gas and Electric       Portland, OR     1898
# 997                Utilities: Gas and Electric       Portland, OR     1898
# 996                           Commercial Banks       Westbury, NY     1902
# ...                                        ...                ...      ...
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 2                           Petroleum Refining         Irving, TX   246204
# 1                        General Merchandisers    Bentonville, AR   482130
#
#       Profits  Employees           City  (City, State) State
# Rank
# 1000       46       5480      Wauwatosa      Wauwatosa    WI
# 999       161      21200         Dublin         Dublin    OH
# 997       172       2646       Portland       Portland    OR
# 997       172       2646       Portland       Portland    OR
# 996       -47       3448       Westbury       Westbury    NY
# ...       ...        ...            ...            ...   ...
# 5        1476      70400  San Francisco  San Francisco    CA
# 4       24083     331000          Omaha          Omaha    NE
# 3       53394     110000      Cupertino      Cupertino    CA
# 2       16150      75600         Irving         Irving    TX
# 1       14694    2300000    Bentonville    Bentonville    AR
#
# [1000 rows x 10 columns]

# %% [markdown]
# 8. b. Does every state in the USA (out of 50) has a company in the database? Which state is the most popular one?

# %%
fortune.State.nunique()
#only 45 states
# Out:
# 45

# %%
fortune['State'].value_counts()[:5]
#CA, and here are an extra 5
# Out:
#  CA    108
#  TX     99
#  NY     95
#  IL     64
#  OH     55
# Name: State, dtype: int64

# %% [markdown]
# 9. What are the names of the companies which are located in NY and have a rank lower than 50?

# %%
fortune[(fortune['City']=='New York')]
# Out:
#                                Company              Sector  \
# Rank
# 992                             Revlon  Household Products
# 967                            Griffon  Household Products
# 877                G-III Apparel Group             Apparel
# 844   Mutual of America Life Insurance          Financials
# 840                       J.Crew Group           Retailing
# ...                                ...                 ...
# 49                                 AIG          Financials
# 40                             MetLife          Financials
# 29                           Citigroup          Financials
# 23                   J.P. Morgan Chase          Financials
# 13                             Verizon  Telecommunications
#
#                                       Industry      Location  Revenue  \
# Rank
# 992            Household and Personal Products  New York, NY     1914
# 967                Home Equipment, Furnishings  New York, NY     2016
# 877                                    Apparel  New York, NY     2344
# 844           Insurance: Life, Health (Mutual)  New York, NY     2495
# 840               Specialty Retailers: Apparel  New York, NY     2506
# ...                                        ...           ...      ...
# 49    Insurance: Property and Casualty (Stock)  New York, NY    58327
# 40             Insurance: Life, Health (stock)  New York, NY    69951
# 29                            Commercial Banks  New York, NY    88275
# 23                            Commercial Banks  New York, NY   101006
# 13                          Telecommunications  New York, NY   131620
#
#       Profits  Employees      City (City, State) State
# Rank
# 992        56       5700  New York      New York    NY
# 967        34       6000  New York      New York    NY
# 877       114       8919  New York      New York    NY
# 844        65       1093  New York      New York    NY
# 840     -1243      10450  New York      New York    NY
# ...       ...        ...       ...           ...   ...
# 49       2196      66400  New York      New York    NY
# 40       5310      69000  New York      New York    NY
# 29      17242     231000  New York      New York    NY
# 23      24442     234598  New York      New York    NY
# 13      17879     177700  New York      New York    NY
#
# [72 rows x 10 columns]

# %% [markdown]
# 10. Which sector have (on average) losses? Which sector is the most profitable?

# %% [markdown]
# 11. a. Add a new column to the database after the Profits column called Rev/Emp which holds the revenues each employee brings to the company.

# %% [markdown]
# 11. b. For each sector and state, what is the count, mean and std of Rev/Emp?

# %% [markdown]
# 12. We want to add for each company its Ticker. To do that, join the data from the file "compaines.csv" with your original data, and only keep the column 'ticker' from the new data. The data should be joined based on the columns "Company", in the fotune1000 database and "short name", in the companies data base.
# <br> Make sure to change the column name to "Ticker".

# %% [markdown]
# 13. Save your updated database to a new file and name it fortune1000_extended.csv.
